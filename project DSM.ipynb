# %%
# IMPORT libirary 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:\\FACULTY\\archive_4\\walmart-sales-dataset-of-45stores.csv")
df=pd.DataFrame(data)
data.head(356)
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0        1  05-02-2010    1643690.90             0        42.31       2.572
# 1        1  12-02-2010    1641957.44             1        38.51       2.548
# 2        1  19-02-2010    1611968.17             0        39.93       2.514
# 3        1  26-02-2010    1409727.59             0        46.63       2.561
# 4        1  05-03-2010    1554806.68             0        46.50       2.625
# ..     ...         ...           ...           ...          ...         ...
# 351      3  06-05-2011     413042.12             0        69.45       3.906
# 352      3  13-05-2011     386312.68             0        79.87       3.899
# 353      3  20-05-2011     364603.13             0        75.79       3.907
# 354      3  27-05-2011     369350.60             0        84.41       3.786
# 355      3  03-06-2011     394507.84             0        84.29       3.699
#
#             CPI  Unemployment
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
data.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
data.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dropna(inplace=True)

# %%
#TO know who store max sales
Total_price=data.groupby("Store")["Weekly_Sales"].sum().sort_values(ascending=False)

# %%
Total_price.head()
# Out:
# Store
# 20    3.013978e+08
# 4     2.995440e+08
# 14    2.889999e+08
# 13    2.865177e+08
# 2     2.753824e+08
# Name: Weekly_Sales, dtype: float64

# %%
data_std=data.groupby("Store")["Weekly_Sales"].std().sort_values(ascending=False)

# %%
data_std.head()
# Out:
# Store
# 14    317569.949476
# 10    302262.062504
# 20    275900.562742
# 4     266201.442297
# 13    265506.995776
# Name: Weekly_Sales, dtype: float64

# %%
# Assuming 'df' is your DataFrame
# Convert the 'Date' column to datetime64 with the correct format
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Verify the changes
print(df["Date"].dtype)
# Out:
# datetime64[ns]

# %%
plt.hist(df['Weekly_Sales'], bins=50)
plt.title('Distribution of Weekly Sales')
plt.xlabel('Weekly Sales')
plt.ylabel('Frequency')
plt.show()

# %%
#  Temperature
plt.hist(df['Temperature'], bins=50)
plt.title('Distribution of Temperature')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.show()

# %%
#  Fuel_Price
plt.hist(df['Fuel_Price'], bins=50)
plt.title('Distribution of Fuel Price')
plt.xlabel('Fuel Price')
plt.ylabel('Frequency')
plt.show()

# %%
# CPI
plt.hist(df['CPI'], bins=50)
plt.title('Distribution of CPI')
plt.xlabel('CPI')
plt.ylabel('Frequency')
plt.show()

# %%
# Unemployment
plt.hist(df['Unemployment'], bins=50)
plt.title('Distribution of Unemployment')
plt.xlabel('Unemployment')
plt.ylabel('Frequency')
plt.show()

# %%
# Assuming 'Date' column is already in datetime format
# Extract month from 'Date' column and create a new 'Month' column
df['Month'] = df['Date'].dt.month

# Group by month and sum the sales
monthly_sales = df.groupby('Month')['Weekly_Sales'].sum()

# Group by month and sum the weekly sales
monthly_sales = df.groupby('Month')['Weekly_Sales'].sum()

# Plotting month-wise sales
plt.figure(figsize=(14, 7), dpi=88)
plt.bar(monthly_sales.index, monthly_sales.values)
plt.xlabel('Months')
plt.ylabel('Weekly Sales')
plt.title('Monthwise Sales')
plt.show()

# %%
 SuperBowl=['2010-02-12', '2011-02-11', '2012-02-10']
LabourDay=['2010-09-10', '2011-09-09', '2012-09-07']
ThanksGiving=['2010-11-26', '2011-11-25']
Christmas=['2010-12-31', '2011-12-30']

# %%
Super_Bowl_sales = df.loc[df['Date'].isin(SuperBowl), 'Weekly_Sales'].mean()
Super_Bowl_sales_rounded = round(Super_Bowl_sales, 2)

Labour_Day_sales = df.loc[df['Date'].isin(LabourDay), 'Weekly_Sales'].mean()
Labour_Day_sales_rounded = round(Labour_Day_sales, 2)

Thanksgiving_sales = df.loc[df['Date'].isin(ThanksGiving), 'Weekly_Sales'].mean()
Thanksgiving_sales_rounded = round(Thanksgiving_sales, 2)

Christmas_sales = df.loc[df['Date'].isin(Christmas), 'Weekly_Sales'].mean()
Christmas_sales_rounded = round(Christmas_sales, 2)

print("Super Bowl Sales:", Super_Bowl_sales_rounded)
print("Labour Day Sales:", Labour_Day_sales_rounded)
print("Thanksgiving Sales:", Thanksgiving_sales_rounded)
print("Christmas Sales:", Christmas_sales_rounded)
# Out:
# Super Bowl Sales: 1079127.99
# Labour Day Sales: 1042427.29
# Thanksgiving Sales: 1471273.43
# Christmas Sales: 960833.11

# %%
# Extract year from 'Date' column and create a new 'Year' column
df['Year'] = df['Date'].dt.year

# Group by year and sum the weekly sales
yearly_sales = df.groupby('Year')['Weekly_Sales'].sum()

# Plotting year-wise sales
plt.figure(figsize=(14, 7), dpi=88)
plt.bar(yearly_sales.index, yearly_sales.values)
plt.xlabel('Year')
plt.ylabel('Weekly Sales')
plt.title('Yearwise Sales')
plt.show()

# %%
# Calculate mean sales for non-holiday weeks
non_holiday_mean_sales = df[df['Holiday_Flag'] == 0]['Weekly_Sales'].mean()

# Find holidays with higher sales than the mean sales in non-holiday weeks
high_sales_holidays = df[(df['Holiday_Flag'] == 1) & (df['Weekly_Sales'] > non_holiday_mean_sales)]['Date'].unique()
print("Holidays with higher sales than non-holiday mean sales:", high_sales_holidays)
# Out:
# Holidays with higher sales than non-holiday mean sales: <DatetimeArray>
# ['2010-02-12 00:00:00', '2010-09-10 00:00:00', '2010-11-26 00:00:00',
#  '2010-12-31 00:00:00', '2011-02-11 00:00:00', '2011-09-09 00:00:00',
#  '2011-11-25 00:00:00', '2011-12-30 00:00:00', '2012-02-10 00:00:00',
#  '2012-09-07 00:00:00']
# Length: 10, dtype: datetime64[ns]

# %%
df['Year'] = pd.to_datetime(df['Date']).dt.year

# Group bymonth and year andsum the weekly saless 
monthly_sales = df.groupby(['Year', 'Month'])['Weekly_Sales'].sum()

# Plot GROUB monthly sales
plt.figure(figsize=(12, 6))
monthly_sales.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales')
plt.show()

# Group the data by every 4 months
df['3_Months'] = (df['Month'] - 1) // 3 + 1
four_monthly_sales = df.groupby(['Year', '3_Months'])['Weekly_Sales'].sum()

# Plot every 4 months sales
plt.figure(figsize=(10, 5))
four_monthly_sales.plot(kind='bar')
plt.xlabel('3 Months')
plt.ylabel('Total Sales')
plt.title('Sales semster Every 4 Months')
plt.show()

# %%
# Scatter plots
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.scatter(df['Temperature'], df['Weekly_Sales'], color='blue', alpha=0.5)
plt.xlabel('Temperature')
plt.ylabel('Weekly Sales')
plt.title('Temperature vs. Weekly Sales')

plt.subplot(2, 2, 2)
plt.scatter(df['Fuel_Price'], df['Weekly_Sales'], color='green', alpha=0.5)
plt.xlabel('Fuel Price')
plt.ylabel('Weekly Sales')
plt.title('Fuel Price vs. Weekly Sales')

plt.subplot(2, 2, 3)
plt.scatter(df['CPI'], df['Weekly_Sales'], color='red', alpha=0.5)
plt.xlabel('CPI')
plt.ylabel('Weekly Sales')
plt.title('CPI vs. Weekly Sales')

plt.subplot(2, 2, 4)
plt.scatter(df['Unemployment'], df['Weekly_Sales'], color='orange', alpha=0.5)
plt.xlabel('Unemployment')
plt.ylabel('Weekly Sales')
plt.title('Unemployment vs. Weekly Sales')

plt.tight_layout()
plt.show()

# %%
 # 1-Weekly sales decrease as the temperature decreases and increase between 20-100
    
 # 2-fuel price is increase in range between 2.50-4.25
 # 3- weekly sales is nil between 140 and 180
 # 4- weekly sales is decrease between 10-14

# %%
Super_Bowl = ['12-2-2010', '11-2-2011', '10-2-2012']
Labour_Day = ['10-9-2010', '9-9-2011', '7-9-2012']
Thanksgiving = ['26-11-2010', '25-11-2011']
Christmas = ['31-12-2010', '30-12-2011']
Super_Bowl = pd.to_datetime(Super_Bowl, format='%d-%m-%Y')
Super_Bowl_sales = df.loc[df.Date.isin(Super_Bowl)]['Weekly_Sales'].mean().round(2)
Labour_Day_sales = df.loc[df.Date.isin(Labour_Day)]['Weekly_Sales'].mean().round(2)
Thanksgiving_sales = df.loc[df.Date.isin(Thanksgiving) ]['Weekly_Sales'].mean().round(2)
Christmas_sales = df.loc[df.Date.isin(Christmas) ]['Weekly_Sales'].mean().round(2)
holiday_sales = {
    'Super Bowl': [Super_Bowl_sales],
    'Labour Day': [Labour_Day_sales],
    'Thanksgiving': [Thanksgiving_sales],
    'Christmas': [Christmas_sales]
}
print(holiday_sales)
# Out:
# {'Super Bowl': [1079127.99], 'Labour Day': [1039182.83], 'Thanksgiving': [1471273.43], 'Christmas': [960833.11]}

# %%
non_holiday_sales = df[df["Holiday_Flag"] == 0]["Weekly_Sales"].mean().round(2)
print("Average weekly sales during non-holiday days:", non_holiday_sales)
# Out:
# Average weekly sales during non-holiday days: 1041256.38

# %%
print("Average weekly sales during holidays:")
print(holiday_sales)

print("\nAverage weekly sales during non-holiday days:", non_holiday_sales)
# Out:
# Average weekly sales during holidays:
# {'Super Bowl': [1079127.99], 'Labour Day': [1039182.83], 'Thanksgiving': [1471273.43], 'Christmas': [960833.11]}
#
# Average weekly sales during non-holiday days: 1041256.38
